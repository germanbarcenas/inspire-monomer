# %% [markdown]
# 04/14/20
#
# Take the distance of DA16 and CY5, and the distsnce of DA16 and DA15 centers of mass.
# Use this as the

# %%
import MDAnalysis as mda

# %%
TPR = "system.tpr"
XTC1 = "da15.xtc"

u1 = mda.Universe(TPR, XTC1)
with mda.Writer("md.xyz", n_atoms=u.atoms.n_atoms) as xyz:
   for ts in u1.trajectory:
        xyz.write(ts)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-529f19bb3dcb> in <module>
#       2 XTC1 = "da15.xtc"
#       3
# ----> 4 u1 = mda.Universe(TPR, XTC1)
#       5 with mda.Writer("md.xyz", n_atoms=u.atoms.n_atoms) as xyz:
#       6    for ts in u1.trajectory:
#
# ~/miniconda3/envs/gromacs/lib/python3.8/site-packages/MDAnalysis/core/universe.py in __init__(self, *args, **kwargs)
#     298                         errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     299                         # Runs if the error is propagated due to no permission / file not found
# --> 300                         six.reraise(*sys.exc_info())
#     301                     else:
#     302                         # Runs when the parser fails
#
# ~/miniconda3/envs/gromacs/lib/python3.8/site-packages/six.py in reraise(tp, value, tb)
# ...

# %%
TPR = "system.tpr"
XTC2 = "da16.xtc"

u2 = mda.Universe(TPR, XTC2)
with mda.Writer("md.xyz", n_atoms=u.atoms.n_atoms) as xyz:
   for ts in u2.trajectory:
        xyz.write(ts)

# %%
TPR = "system.tpr"
XTC3 = "cy5.xtc"

u2 = mda.Universe(TPR, XTC3)
with mda.Writer("md.xyz", n_atoms=u.atoms.n_atoms) as xyz:
   for ts in u2.trajectory:
        xyz.write(ts)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e550c44b10e3> in <module>
#       2 XTC3 = "cy5.xtc"
#       3
# ----> 4 u2 = mda.Universe(TPR, XTC3)
#       5 with mda.Writer("md.xyz", n_atoms=u.atoms.n_atoms) as xyz:
#       6    for ts in u2.trajectory:
#
# ~/miniconda3/envs/gromacs/lib/python3.8/site-packages/MDAnalysis/core/universe.py in __init__(self, *args, **kwargs)
#     298                         errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     299                         # Runs if the error is propagated due to no permission / file not found
# --> 300                         six.reraise(*sys.exc_info())
#     301                     else:
#     302                         # Runs when the parser fails
#
# ~/miniconda3/envs/gromacs/lib/python3.8/site-packages/six.py in reraise(tp, value, tb)
# ...

# %%
vector_1 = [0, 1]
vector_2 = [1, 0]

unit_vector_1 = vector_1 / np.linalg.norm(vector_1)
unit_vector_2 = vector_2 / np.linalg.norm(vector_2)
dot_product = np.dot(unit_vector_1, unit_vector_2)
angle = np.arccos(dot_product)
